# %% [markdown]
# # Program 2

# %% [markdown]
# **The Problem**
#
# The problem that you will be solving is called the SELECTION problem.
#
# **SELECTION**
#
# Input A sequence of n ≥ 2 numbers and an integer k, 1 ≤ k ≤ n
#
# Output The k
# th smallest number in the sequence.

# %% [markdown]
# **Approach Used**
# Viannys

# %% [markdown]
# **High-level pseudocode** Viannys

# %% [markdown]
# **Explaination / Justification** Viannys
